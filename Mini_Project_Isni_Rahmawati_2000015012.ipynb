# %% [markdown]
# #Membandingkan sugarpercent dengan pricepercent pada dataset The Ultimate Halloween Candy Power Ranking

# %% [markdown]
# ##Latar Belakang Dataset

# %% [markdown]
# Permen atau gula-gula adalah makanan berkalori tinggi yang pada umumnya berbahan dasar gula, air, dan sirup fruktosa.Tingginya kadar gula dalam permen membuatnya diklaim sebagai salah satu penyebab gigi berlubang. Para ahli pernah menemukan permen purba di Mesir sekitar 3500 tahun yang lalu. Dan di tempat yang lain juga pernah ditemukan gumpalan madu kering yang diduga dijadikan permen oleh manusia purba pada saat itu. Kegemaran yang awalnya hanya iseng belaka ini kemudian mendorong bangsa Mesir, Arab, dan Cina kuno untuk membuat racikan manisan madu dengan berbagai macam rasa. Mulai dari rasa buah buahan sampai kacang kacangan. Perkembangan pembuatan permen ini juga di pengaruhi oleh kebiasaan makan coklat yang di populerkan suku Indian, Aztec, dan Maya.
#
# Dataset `The Ultimate Halloween Candy Power Ranking` ini menyajikan macam - macam rasa, tingkat ke kerasan permen, kadar gula, persentase harga, dan persentase kemenangan
#
# Dataset ini dibuat untuk membuktikan mana permen terbaik atau setidaknya yang paling populer saat itu.

# %% [markdown]
# ## Pertanyaan Analisis

# %% [markdown]
# Membandingkan Variabel Sugarpercent dengan Pricepercent pada baris 0 sampai 10

# %% [markdown]
# ##EDA (Exploratory Data Analysis)

# %%
#import data
import pandas as pd                           
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
candy = pd.read_csv('https://raw.githubusercontent.com/isnirahmawati/PSDS-Kelas-Dasar-3.0/main/candy.csv')
candy.head()
# Out:
#   competitorname  chocolate  fruity  ...  sugarpercent  pricepercent  winpercent
# 0      100 Grand          1       0  ...         0.732         0.860   66.971725
# 1   3 Musketeers          1       0  ...         0.604         0.511   67.602936
# 2       One dime          0       0  ...         0.011         0.116   32.261086
# 3    One quarter          0       0  ...         0.011         0.511   46.116505
# 4      Air Heads          0       1  ...         0.906         0.511   52.341465
#
# [5 rows x 13 columns]

# %%
candy.shape
# Out:
# (85, 13)

# %% [markdown]
# Dataset candy memiliki data dengan 13 kolom dan 85 baris

# %% [markdown]
# # Variabel Pada Dataset

# %%
candy.columns.values
# Out:
# array(['competitorname', 'chocolate', 'fruity', 'caramel',
#        'peanutyalmondy', 'nougat', 'crispedricewafer', 'hard', 'bar',
#        'pluribus', 'sugarpercent', 'pricepercent', 'winpercent'],
#       dtype=object)

# %%
candy.dtypes
# Out:
# competitorname       object
# chocolate             int64
# fruity                int64
# caramel               int64
# peanutyalmondy        int64
# nougat                int64
# crispedricewafer      int64
# hard                  int64
# bar                   int64
# pluribus              int64
# sugarpercent        float64
# pricepercent        float64
# winpercent          float64
# dtype: object

# %%
candy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85 entries, 0 to 84
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   competitorname    85 non-null     object
#  1   chocolate         85 non-null     int64
#  2   fruity            85 non-null     int64
#  3   caramel           85 non-null     int64
#  4   peanutyalmondy    85 non-null     int64
#  5   nougat            85 non-null     int64
#  6   crispedricewafer  85 non-null     int64
#  7   hard              85 non-null     int64
#  8   bar               85 non-null     int64
#  9   pluribus          85 non-null     int64
#  10  sugarpercent      85 non-null     float64
#  11  pricepercent      85 non-null     float64
#  12  winpercent        85 non-null     float64
# dtypes: float64(3), int64(9), object(1)
# memory usage: 8.8+ KB

# %% [markdown]
# untuk mengetahui tipe-tipe data masing-masing variabel dan nama-nama variabel dalam dataset candy

# %% [markdown]
# # Mengecek Missing Data

# %%
candy.isnull().sum()
# Out:
# competitorname      0
# chocolate           0
# fruity              0
# caramel             0
# peanutyalmondy      0
# nougat              0
# crispedricewafer    0
# hard                0
# bar                 0
# pluribus            0
# sugarpercent        0
# pricepercent        0
# winpercent          0
# dtype: int64

# %%
sns.heatmap(candy.isnull(),cbar=False,yticklabels=False,cmap = 'viridis')

# %% [markdown]
# # Mengecek Outlier

# %%
candy1=candy.select_dtypes(include=['float64', 'int64'])#Memilih kolom numerik

sns.boxplot(x="variable", y="value", color='red',orient='v', data=pd.melt(candy1))
plt.tight_layout()

# %% [markdown]
# # Melihat Korelasi Data

# %%
k = len(candy1.columns)
cm = candy1.corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %% [markdown]
# # Melihat Statistik Data

# %%
candy.describe()
# Out:
#        chocolate     fruity    caramel  ...  sugarpercent  pricepercent  winpercent
# count  85.000000  85.000000  85.000000  ...     85.000000     85.000000   85.000000
# mean    0.435294   0.447059   0.164706  ...      0.478647      0.468882   50.316764
# std     0.498738   0.500140   0.373116  ...      0.282778      0.285740   14.714357
# min     0.000000   0.000000   0.000000  ...      0.011000      0.011000   22.445341
# 25%     0.000000   0.000000   0.000000  ...      0.220000      0.255000   39.141056
# 50%     0.000000   0.000000   0.000000  ...      0.465000      0.465000   47.829754
# 75%     1.000000   1.000000   0.000000  ...      0.732000      0.651000   59.863998
# max     1.000000   1.000000   1.000000  ...      0.988000      0.976000   84.180290
#
# [8 rows x 12 columns]

# %% [markdown]
# # Plot Distribusi Data Numerik

# %%
x = candy1.columns.values
number_of_columns=len(candy1.columns)
number_of_rows = len(x)-1/number_of_columns
plt.figure(figsize=(2*number_of_columns,5*number_of_rows))
for i in range(0,len(x)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.distplot(candy[x[i]],kde=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#
# ...

# %% [markdown]
# # Pairplot

# %%
y = sns.pairplot(candy1, hue="caramel")

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# # Seleksi Kolom

# %%
candy=candy.drop(columns=['winpercent'])
candy.head()
# Out:
#   competitorname  chocolate  fruity  ...  pluribus  sugarpercent  pricepercent
# 0      100 Grand          1       0  ...         0         0.732         0.860
# 1   3 Musketeers          1       0  ...         0         0.604         0.511
# 2       One dime          0       0  ...         0         0.011         0.116
# 3    One quarter          0       0  ...         0         0.011         0.511
# 4      Air Heads          0       1  ...         0         0.906         0.511
#
# [5 rows x 12 columns]

# %% [markdown]
# # Mengisis NaN

# %%
candy['nougat'].value_counts()
# Out:
# 0    78
# 1     7
# Name: nougat, dtype: int64

# %%
candy['nougat'] = candy['nougat'].replace(np.nan, "1")
candy.head()
# Out:
#   competitorname  chocolate  fruity  ...  pluribus  sugarpercent  pricepercent
# 0      100 Grand          1       0  ...         0         0.732         0.860
# 1   3 Musketeers          1       0  ...         0         0.604         0.511
# 2       One dime          0       0  ...         0         0.011         0.116
# 3    One quarter          0       0  ...         0         0.011         0.511
# 4      Air Heads          0       1  ...         0         0.906         0.511
#
# [5 rows x 12 columns]

# %%
candy['pricepercent']=candy['pricepercent'].fillna(candy['pricepercent'].mean())
candy.head()
# Out:
#   competitorname  chocolate  fruity  ...  pluribus  sugarpercent  pricepercent
# 0      100 Grand          1       0  ...         0         0.732         0.860
# 1   3 Musketeers          1       0  ...         0         0.604         0.511
# 2       One dime          0       0  ...         0         0.011         0.116
# 3    One quarter          0       0  ...         0         0.011         0.511
# 4      Air Heads          0       1  ...         0         0.906         0.511
#
# [5 rows x 12 columns]

# %%
candy[['pricepercent','nougat']].isnull().sum()
# Out:
# pricepercent    0
# nougat          0
# dtype: int64

# %% [markdown]
# # Melakukan Pengkodean(Encoding)

# %%
candy['caramel'].value_counts()
# Out:
# 0    71
# 1    14
# Name: caramel, dtype: int64

# %%
candy['fruity'].value_counts()
# Out:
# 0    47
# 1    38
# Name: fruity, dtype: int64

# %%
candy['pricepercent'].value_counts()
# Out:
# 0.511    12
# 0.325    10
# 0.116     9
# 0.651     9
# 0.767     6
# 0.860     4
# 0.465     4
# 0.918     4
# 0.220     3
# 0.279     3
# 0.976     2
# 0.034     2
# 0.755     1
# 0.081     1
# 0.093     1
# 0.965     1
# 0.058     1
# 0.255     1
# 0.011     1
# 0.069     1
# 0.104     1
# 0.441     1
# 0.906     1
# 0.848     1
# 0.313     1
# 0.837     1
# 0.453     1
# 0.267     1
# 0.023     1
# Name: pricepercent, dtype: int64

# %% [markdown]
# ## Data Visualization

# %%
candy = pd.read_csv('https://raw.githubusercontent.com/isnirahmawati/PSDS-Kelas-Dasar-3.0/main/candy.csv')
candy.head()
# Out:
#   competitorname  chocolate  fruity  ...  sugarpercent  pricepercent  winpercent
# 0      100 Grand          1       0  ...         0.732         0.860   66.971725
# 1   3 Musketeers          1       0  ...         0.604         0.511   67.602936
# 2       One dime          0       0  ...         0.011         0.116   32.261086
# 3    One quarter          0       0  ...         0.011         0.511   46.116505
# 4      Air Heads          0       1  ...         0.906         0.511   52.341465
#
# [5 rows x 13 columns]

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
df_candy = pd.read_csv('https://raw.githubusercontent.com/isnirahmawati/PSDS-Kelas-Dasar-3.0/main/candy.csv')
df_candy
# Out:
#                 competitorname  chocolate  ...  pricepercent  winpercent
# 0                    100 Grand          1  ...         0.860   66.971725
# 1                 3 Musketeers          1  ...         0.511   67.602936
# 2                     One dime          0  ...         0.116   32.261086
# 3                  One quarter          0  ...         0.511   46.116505
# 4                    Air Heads          0  ...         0.511   52.341465
# ..                         ...        ...  ...           ...         ...
# 80                   Twizzlers          0  ...         0.116   45.466282
# 81                    Warheads          0  ...         0.116   39.011898
# 82        WelchÕs Fruit Snacks          0  ...         0.313   44.375519
# 83  WertherÕs Original Caramel          0  ...         0.267   41.904308
# 84                    Whoppers          1  ...         0.848   49.524113
#
# [85 rows x 13 columns]

# %% [markdown]
# Membandingkan Variabel Sugarpercent dengan Pricepercent pada baris 0 sampai 10

# %%
candy_x = candy.iloc[:11, 10:12]
candy_x
# Out:
#     sugarpercent  pricepercent
# 0          0.732         0.860
# 1          0.604         0.511
# 2          0.011         0.116
# 3          0.011         0.511
# 4          0.906         0.511
# 5          0.465         0.767
# 6          0.604         0.767
# 7          0.313         0.511
# 8          0.906         0.325
# 9          0.604         0.325
# 10         0.604         0.511

# %%
import sys
import matplotlib
matplotlib.use('Agg')

import matplotlib.pyplot as plt
import numpy as np

x = np.array([0.732, 0.604, 0.011, 0.011, 0.906, 0.465, 0.604, 0.313, 0.906, 0.604, 0.604])
y = np.array([0.860, 0.511, 0.116, 0.511, 0.511, 0.767, 0.767, 0.511, 0.325, 0.325, 0.511])
plt.title("Sugarpercent vs Pricepercent",size = 16)
plt.xlabel("Sugarpercent")
plt.ylabel("Pricepercent")

plt.scatter(x, y)
plt.show()
